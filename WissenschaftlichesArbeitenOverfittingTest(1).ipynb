# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.layers import Conv2D, MaxPooling2D
cifar10 = tf.keras.datasets.cifar10
import matplotlib.pyplot as plt

# %%
# Aufteilung in Training- und Testset
(x_train, y_train),(x_test, y_test) = cifar10.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

label_names = ['airplane', 'automobile','bird','cat','deer','dog','frog','horse','ship','truck']
num_filters = 8
filter_size = 3
pool_size = 2
#
model2 = Sequential([
  Conv2D(num_filters, filter_size, input_shape=(32, 32, 3), activation='relu'),
  MaxPooling2D(pool_size=pool_size),
  Flatten(input_shape=(32, 32, 3)),
  Dense(255,activation='relu'),
  Dense(10, activation=tf.nn.softmax)
])
 
# Crossentropy für die 10 Zahlen Klassen
model2.compile(optimizer='sgd',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
 
# Modellfitting und Evaluation
fit_history = model2.fit(x_train, y_train, epochs=15, validation_data=(x_test, y_test))
print('')
print('Performance on test data: ', model2.evaluate(x_test, y_test))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 2s 0us/step
# Epoch 1/15
# 1563/1563 [==============================] - 15s 4ms/step - loss: 1.9185 - accuracy: 0.3153 - val_loss: 1.7203 - val_accuracy: 0.4022
# Epoch 2/15
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.6289 - accuracy: 0.4240 - val_loss: 1.6973 - val_accuracy: 0.4043
# Epoch 3/15
# 1563/1563 [==============================] - 5s 4ms/step - loss: 1.4921 - accuracy: 0.4737 - val_loss: 1.4359 - val_accuracy: 0.4919
# Epoch 4/15
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.4012 - accuracy: 0.5053 - val_loss: 1.3826 - val_accuracy: 0.5113
# Epoch 5/15
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.3359 - accuracy: 0.5321 - val_loss: 1.3284 - val_accuracy: 0.5287
# Epoch 6/15
# 1563/1563 [==============================] - 5s 4ms/step - loss: 1.2848 - accuracy: 0.5491 - val_loss: 1.3091 - val_accuracy: 0.5367
# Epoch 7/15
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.2414 - accuracy: 0.5661 - val_loss: 1.3175 - val_accuracy: 0.5367
# Epoch 8/15
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.2046 - accuracy: 0.5815 - val_loss: 1.2817 - val_accuracy: 0.5452
# Epoch 9/15
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.1642 - accuracy: 0.5950 - val_loss: 1.2501 - val_accuracy: 0.5525
# Epoch 10/15
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.1209 - accuracy: 0.6097 - val_loss: 1.2723 - val_accuracy: 0.5562
# Epoch 11/15
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.0820 - accuracy: 0.6244 - val_loss: 1.2153 - val_accuracy: 0.5755
# Epoch 12/15
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.0435 - accuracy: 0.6366 - val_loss: 1.2268 - val_accuracy: 0.5612
# Epoch 13/15
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.0058 - accuracy: 0.6501 - val_loss: 1.2119 - val_accuracy: 0.5744
# Epoch 14/15
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.9715 - accuracy: 0.6638 - val_loss: 1.1839 - val_accuracy: 0.5858
# Epoch 15/15
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.9365 - accuracy: 0.6753 - val_loss: 1.1904 - val_accuracy: 0.5903
#
# 313/313 [==============================] - 1s 3ms/step - loss: 1.1904 - accuracy: 0.5903
# Performance on test data:  [1.1903678178787231, 0.5903000235557556]

# %%
plt.figure(1, figsize = (15,8))
    
plt.subplot(221)  
plt.plot(fit_history.history['accuracy'])  
plt.plot(fit_history.history['val_accuracy'])  
plt.title('model accuracy')  
plt.ylabel('accuracy')  
plt.xlabel('epoch')  
plt.legend(['train', 'validation']) ;
    
plt.subplot(222)  
plt.plot(fit_history.history['loss'])  
plt.plot(fit_history.history['val_loss'])  
plt.title('model loss')  
plt.ylabel('loss')  
plt.xlabel('epoch')  
plt.legend(['train', 'validation']);

# %%
# Aufteilung in Training- und Testset
(x_train, y_train),(x_test, y_test) = cifar10.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

label_names = ['airplane', 'automobile','bird','cat','deer','dog','frog','horse','ship','truck']
num_filters = 8
filter_size = 3
pool_size = 2
#
model2 = Sequential([
  Conv2D(num_filters, filter_size, input_shape=(32, 32, 3), activation='relu'),
  MaxPooling2D(pool_size=pool_size),
  Flatten(input_shape=(32, 32, 3)),
  Dense(128,activation='relu'),
  Dense(10, activation=tf.nn.softmax)
])
 
# Crossentropy für die 10 Zahlen Klassen
model2.compile(optimizer='sgd',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
 
# Modellfitting und Evaluation
fit_history = model2.fit(x_train, y_train, epochs=15, validation_data=(x_test, y_test))
print('')
print('Performance on test data: ', model2.evaluate(x_test, y_test))
# Out:
# Epoch 1/15
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.9316 - accuracy: 0.3052 - val_loss: 1.8022 - val_accuracy: 0.3552
# Epoch 2/15
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.5984 - accuracy: 0.4364 - val_loss: 1.4928 - val_accuracy: 0.4674
# Epoch 3/15
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.4296 - accuracy: 0.4918 - val_loss: 1.4318 - val_accuracy: 0.4779
# Epoch 4/15
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.3348 - accuracy: 0.5285 - val_loss: 1.3301 - val_accuracy: 0.5314
# Epoch 5/15
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.2768 - accuracy: 0.5518 - val_loss: 1.2930 - val_accuracy: 0.5411
# Epoch 6/15
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.2317 - accuracy: 0.5677 - val_loss: 1.2686 - val_accuracy: 0.5492
# Epoch 7/15
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.1900 - accuracy: 0.5835 - val_loss: 1.2760 - val_accuracy: 0.5437
# Epoch 8/15
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.1529 - accuracy: 0.5978 - val_loss: 1.2684 - val_accuracy: 0.5539
# Epoch 9/15
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.1151 - accuracy: 0.6109 - val_loss: 1.2171 - val_accuracy: 0.5698
# Epoch 10/15
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.0802 - accuracy: 0.6247 - val_loss: 1.2003 - val_accuracy: 0.5732
# Epoch 11/15
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.0479 - accuracy: 0.6335 - val_loss: 1.1626 - val_accuracy: 0.5862
# Epoch 12/15
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.0168 - accuracy: 0.6428 - val_loss: 1.2112 - val_accuracy: 0.5758
# Epoch 13/15
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.9854 - accuracy: 0.6553 - val_loss: 1.1599 - val_accuracy: 0.5911
# Epoch 14/15
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.9572 - accuracy: 0.6656 - val_loss: 1.2360 - val_accuracy: 0.5702
# Epoch 15/15
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.9290 - accuracy: 0.6766 - val_loss: 1.1480 - val_accuracy: 0.6014
#
# 313/313 [==============================] - 1s 3ms/step - loss: 1.1480 - accuracy: 0.6014
# Performance on test data:  [1.147957444190979, 0.6014000177383423]

# %%
plt.figure(1, figsize = (15,8))
    
plt.subplot(221)  
plt.plot(fit_history.history['accuracy'])  
plt.plot(fit_history.history['val_accuracy'])  
plt.title('model accuracy')  
plt.ylabel('accuracy')  
plt.xlabel('epoch')  
plt.legend(['train', 'validation']) ;
    
plt.subplot(222)  
plt.plot(fit_history.history['loss'])  
plt.plot(fit_history.history['val_loss'])  
plt.title('model loss')  
plt.ylabel('loss')  
plt.xlabel('epoch')  
plt.legend(['train', 'validation']);

# %%
# Aufteilung in Training- und Testset
(x_train, y_train),(x_test, y_test) = cifar10.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

label_names = ['airplane', 'automobile','bird','cat','deer','dog','frog','horse','ship','truck']
num_filters = 8
filter_size = 3
pool_size = 2
#
model2 = Sequential([
  Conv2D(num_filters, filter_size, input_shape=(32, 32, 3), activation='relu'),
  MaxPooling2D(pool_size=pool_size),
  Flatten(input_shape=(32, 32, 3)),
  Dense(255,activation='relu'),
   Dropout(0.25),
  Dense(10, activation=tf.nn.softmax)
])
 
# Crossentropy für die 10 Zahlen Klassen
model2.compile(optimizer='sgd',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
 
# Modellfitting und Evaluation
fit_history = model2.fit(x_train, y_train, epochs=15, validation_data=(x_test, y_test))
print('')
print('Performance on test data: ', model2.evaluate(x_test, y_test))
# Out:
# Epoch 1/15
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.9458 - accuracy: 0.3020 - val_loss: 1.7680 - val_accuracy: 0.3649
# Epoch 2/15
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.6871 - accuracy: 0.4025 - val_loss: 1.5748 - val_accuracy: 0.4339
# Epoch 3/15
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.5546 - accuracy: 0.4473 - val_loss: 1.4774 - val_accuracy: 0.4679
# Epoch 4/15
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.4720 - accuracy: 0.4760 - val_loss: 1.4266 - val_accuracy: 0.4893
# Epoch 5/15
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.4112 - accuracy: 0.5010 - val_loss: 1.4063 - val_accuracy: 0.4987
# Epoch 6/15
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.3625 - accuracy: 0.5183 - val_loss: 1.3152 - val_accuracy: 0.5320
# Epoch 7/15
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.3117 - accuracy: 0.5395 - val_loss: 1.3105 - val_accuracy: 0.5297
# Epoch 8/15
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.2669 - accuracy: 0.5533 - val_loss: 1.2447 - val_accuracy: 0.5594
# Epoch 9/15
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.2313 - accuracy: 0.5661 - val_loss: 1.2368 - val_accuracy: 0.5575
# Epoch 10/15
# 1563/1563 [==============================] - 5s 4ms/step - loss: 1.1946 - accuracy: 0.5805 - val_loss: 1.2285 - val_accuracy: 0.5667
# Epoch 11/15
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.1624 - accuracy: 0.5923 - val_loss: 1.2266 - val_accuracy: 0.5696
# Epoch 12/15
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.1341 - accuracy: 0.6040 - val_loss: 1.1646 - val_accuracy: 0.5911
# Epoch 13/15
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.1064 - accuracy: 0.6112 - val_loss: 1.1719 - val_accuracy: 0.5878
# Epoch 14/15
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.0816 - accuracy: 0.6201 - val_loss: 1.1643 - val_accuracy: 0.5888
# Epoch 15/15
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.0584 - accuracy: 0.6296 - val_loss: 1.1311 - val_accuracy: 0.6036
#
# 313/313 [==============================] - 1s 2ms/step - loss: 1.1311 - accuracy: 0.6036
# Performance on test data:  [1.1310763359069824, 0.603600025177002]

# %%
plt.figure(1, figsize = (15,8))
    
plt.subplot(221)  
plt.plot(fit_history.history['accuracy'])  
plt.plot(fit_history.history['val_accuracy'])  
plt.title('model accuracy')  
plt.ylabel('accuracy')  
plt.xlabel('epoch')  
plt.legend(['train', 'validation']) ;
    
plt.subplot(222)  
plt.plot(fit_history.history['loss'])  
plt.plot(fit_history.history['val_loss'])  
plt.title('model loss')  
plt.ylabel('loss')  
plt.xlabel('epoch')  
plt.legend(['train', 'validation']);

# %%
(x_train, y_train),(x_test, y_test) = cifar10.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

label_names = ['airplane', 'automobile','bird','cat','deer','dog','frog','horse','ship','truck']
num_filters = 8
filter_size = 3
pool_size = 2
#
model2 = Sequential([
  Conv2D(num_filters, filter_size, input_shape=(32, 32, 3), activation='relu'),
  MaxPooling2D(pool_size=pool_size),
  Flatten(input_shape=(32, 32, 3)),
  Dense(255,activation='relu'),
  Dense(10, activation=tf.nn.softmax)
])
 
# Crossentropy für die 10 Zahlen Klassen
model2.compile(optimizer='sgd',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
 
# Modellfitting und Evaluation
fit_history = model2.fit(x_train, y_train, epochs=10, validation_data=(x_test, y_test))
print('')
print('Performance on test data: ', model2.evaluate(x_test, y_test))
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.9276 - accuracy: 0.3110 - val_loss: 1.6910 - val_accuracy: 0.4194
# Epoch 2/10
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.5923 - accuracy: 0.4394 - val_loss: 1.5125 - val_accuracy: 0.4607
# Epoch 3/10
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.4199 - accuracy: 0.4976 - val_loss: 1.3910 - val_accuracy: 0.5094
# Epoch 4/10
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.3244 - accuracy: 0.5325 - val_loss: 1.3202 - val_accuracy: 0.5304
# Epoch 5/10
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.2598 - accuracy: 0.5572 - val_loss: 1.2906 - val_accuracy: 0.5480
# Epoch 6/10
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.2083 - accuracy: 0.5754 - val_loss: 1.2933 - val_accuracy: 0.5354
# Epoch 7/10
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.1640 - accuracy: 0.5916 - val_loss: 1.2176 - val_accuracy: 0.5751
# Epoch 8/10
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.1211 - accuracy: 0.6087 - val_loss: 1.2260 - val_accuracy: 0.5701
# Epoch 9/10
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.0816 - accuracy: 0.6222 - val_loss: 1.1875 - val_accuracy: 0.5809
# Epoch 10/10
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.0425 - accuracy: 0.6367 - val_loss: 1.2083 - val_accuracy: 0.5788
#
# 313/313 [==============================] - 1s 2ms/step - loss: 1.2083 - accuracy: 0.5788
# Performance on test data:  [1.2083159685134888, 0.5788000226020813]

# %%
plt.figure(1, figsize = (15,8))
    
plt.subplot(221)  
plt.plot(fit_history.history['accuracy'])  
plt.plot(fit_history.history['val_accuracy'])  
plt.title('model accuracy')  
plt.ylabel('accuracy')  
plt.xlabel('epoch')  
plt.legend(['train', 'validation']) ;
    
plt.subplot(222)  
plt.plot(fit_history.history['loss'])  
plt.plot(fit_history.history['val_loss'])  
plt.title('model loss')  
plt.ylabel('loss')  
plt.xlabel('epoch')  
plt.legend(['train', 'validation']);
